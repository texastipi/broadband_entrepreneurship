# %%
import sys
import numpy as np
import pandas as pd
from sodapy import Socrata

# Check versions
print('Python version:', sys.version)
print('Pandas version:', pd.__version__)
# Out:
# Python version: 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]
# Pandas version: 1.1.3

# %%
# Testing FCC API connection
client = Socrata("opendata.fcc.gov",
                "WHT9nk7BMfD3HeJF6rxayRokn",
                username="jwroycechoi@gmail.com",
                password="Wodnjs58640!")

num = range(1, 400)

list_of_dfs = {}

for i in num:
    list_of_dfs[i] = pd.DataFrame.from_records(client.get("whue-6pnt", where="stateabbr='TX' OR stateabbr='KS' OR stateabbr='ME'",
                                                          limit = 25000,
                                                          offset = ((i-1)*25000)))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# /opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
# ...

# %%
# First 10 items of the retrieved dataset
results_df.head(10)
# Out:
#    logrecno provider_id         frn  \
# 0  23234689       57307  0021693924
# 1  68502134       54694  0012369286
# 2  17895741       56004  0004963088
# 3  17929968       56004  0004963088
# 4  69907570       55262  0018756155
# 5   7756421       55661  0028208213
# 6  40497554       67058  0003801651
# 7  25252812       58181  0027216944
# 8  34592126       59520  0021890777
# 9  69023039       54694  0012369286
#
#                                 providername                     dbaname  \
# 0                   Brady Communications LLC    Brady Communications LLC
# 1                       HNS License Sub, LLC                   HughesNet
# 2                               ViaSat, Inc.                  Viasat Inc
# 3                               ViaSat, Inc.                  Viasat Inc
# 4                          VSAT Systems, LLC                  Skycasters
# 5         TGM pinnacle network solutions inc  Pinnacle Network Solutions
# ...

# %%
# Inspect the dataset
results_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   logrecno            50001 non-null  object
#  1   provider_id         50001 non-null  object
#  2   frn                 50001 non-null  object
#  3   providername        50001 non-null  object
#  4   dbaname             50001 non-null  object
#  5   holdingcompanyname  50001 non-null  object
#  6   hoconum             50001 non-null  object
#  7   hocofinal           50001 non-null  object
#  8   stateabbr           50001 non-null  object
#  9   blockcode           50001 non-null  object
#  10  techcode            50001 non-null  object
#  11  consumer            50001 non-null  object
#  12  maxaddown           50001 non-null  object
#  13  maxadup             50001 non-null  object
#  14  business            50001 non-null  object
# dtypes: object(15)
# ...

# %%
client.get_all("whue-6pnt", where="stateabbr='TX' OR stateabbr='KS' OR stateabbr='ME'")
# Out:
# <generator object Socrata.get_all at 0x7fc94ddff190>

# %%
num = range(1,10)
print(num)
# Out:
# range(1, 10)
